# %%
import pandas as pd
import requests
import pandas as pd
import json

# %%
# data:

# - cars: "Verkehrszähldaten motorisierter Individualverkehr"
# https://data.bs.ch/explore/dataset/100006/map/?sort=datetimefrom&location=15,47.54951,7.59891&basemap=a95210

# - bikes: "Verkehrszähldaten Velos und Fussgänger"
# https://data.bs.ch/explore/dataset/100013/map/?sort=datetimefrom&location=20,47.55037,7.56745&basemap=a95210

# %%
url_cars = "https://data.bs.ch/api/records/1.0/search/?dataset=100006&q=&sort=datetimefrom&facet=zst_nr&facet=sitename&facet=datetimefrom&facet=datetimeto&facet=directionname&facet=lanename&facet=valuesapproved&facet=valuesedited&facet=year&facet=month&facet=day&facet=weekday&facet=timefrom"
url_bikes = "https://data.bs.ch/api/records/1.0/search/?dataset=100013&q=&sort=datetimefrom&facet=zst_nr&facet=sitename&facet=datetimefrom&facet=datetimeto&facet=directionname&facet=lanename&facet=valuesapproved&facet=valuesedited&facet=traffictype&facet=year&facet=month&facet=day&facet=weekday&facet=timefrom"

# %%
data = requests.get(url_cars).json()
print(data)
# Out:
# {'nhits': 802248, 'parameters': {'dataset': '100006', 'timezone': 'UTC', 'rows': 10, 'sort': ['datetimefrom'], 'format': 'json', 'facet': ['zst_nr', 'sitename', 'datetimefrom', 'datetimeto', 'directionname', 'lanename', 'valuesapproved', 'valuesedited', 'year', 'month', 'day', 'weekday', 'timefrom']}, 'records': [{'datasetid': '100006', 'recordid': '6402a1087c7a508d95bd2aff8668f4857a753fdf', 'fields': {'andere': 0, 'lief': 3, 'pw0': 0, 'sattelzug': 0, 'month': 5, 'zst_nr': '401', 'year': '2020', 'total': 55, 'timefrom': '23:00', 'valuesapproved': 0, 'sitename': '401 Luzernerring-Brücke', 'lw': 0, 'directionname': '2 Flughafenstrasse', 'lief0': 0, 'lanename': 'Spur 2', 'lief_aufl': 0, 'datetimeto': '2020-05-19T23:00:00+00:00', 'bus': 0, 'hourfrom': 23, 'traffictype': 'MIV', 'date': '20.05.2020', 'day': 20, 'pw': 52, 'valuesedited': 0, 'lw0': 0, 'datetimefrom': '2020-05-20T22:00:00+00:00', 'geo_point_2d': [47.5699125893, 7.57284015165], 'timeto': '00:00', 'lanecode': 2, 'weekday': 2, 'mr': 0, 'sitecode': '00000401'}, 'geometry': {'type': 'Point', 'coordinates': [7.57284015165, 47.5699125893]}, 'record_timestamp': '2020-05-22T06:52:06.659000+00:00'}, {'datasetid': '100006', 'recordid': '8af3954dc0eb1ae29a5992952bf73ef5a79b9028', 'fields': {'andere': 0, 'lief': 5, 'pw0': 0, 'sattelzug': 0, 'month': 5, 'zst_nr': '420', 'year': '2020', 'total': 190, 'timefrom': '23:00', 'valuesapproved': 0, 'sitename': '420 Nauenstrasse 73', 'lw': 0, 'directionname': '1 nach Grosspeter', 'lief0': 0, 'lanename': 'Spur 1', 'lief_aufl': 0, 'datetimeto': '2020-05-19T23:00:00+00:00', 'bus': 1, 'hourfrom': 23, 'traffictype': 'MIV', 'date': '20.05.2020', 'day': 20, 'pw': 180, 'valuesedited': 0, 'lw0': 1, 'datetimefrom': '2020-05-20T22:00:00+00:00', 'geo_point_2d': [47.5463057195, 7.59562321755], 'timeto': '00:00', 'lanecode': 1, 'weekday': 2, 'mr': 3, 'sitecode': '00000420'}, 'geometry': {'type': 'Point', 'coordinates': [7.59562321755, 47.5463057195]}, 'record_timestamp': '2020-05-22T06:52:06.659000+00:00'}, {'datasetid': '100006', 'recordid': 'c7aa48c0694143037d0c9ca6f935ba15b2db7cdf', 'fields': {'andere': 0, 'lief': 0, 'pw0': 0, 'sattelzug': 0, 'month': 5, 'zst_nr': '411', 'year': '2020', 'total': 12, 'timefrom': '23:00', 'valuesapproved': 0, 'sitename': '411 Fasanenstrasse (DB-Brücke)', 'lw': 0, 'directionname': '2 von Riehen (1=rechte S mit ÖV-Bus, 2=Unterführung)', 'lief0': 0, 'lanename': 'Spur 3', 'lief_aufl': 0, 'datetimeto': '2020-05-19T23:00:00+00:00', 'bus': 0, 'hourfrom': 23, 'traffictype': 'MIV', 'date': '20.05.2020', 'day': 20, 'pw': 11, 'valuesedited': 0, 'lw0': 0, 'datetimefrom': '2020-05-20T22:00:00+00:00', 'geo_point_2d': [47.573908258, 7.60222303084], 'timeto': '00:00', 'lanecode': 3, 'weekday': 2, 'mr': 1, 'sitecode': '00000411'}, 'geometry': {'type': 'Point', 'coordinates': [7.60222303084, 47.573908258]}, 'record_timestamp': '2020-05-22T06:52:06.659000+00:00'}, {'datasetid': '100006', 'recordid': 'faf3667b442488ea3157ac54e8d12f123695d573', 'fields': {'andere': 0, 'lief': 1, 'pw0': 0, 'sattelzug': 0, 'month': 5, 'zst_nr': '411', 'year': '2020', 'total': 14, 'timefrom': '23:00', 'valuesapproved': 0, 'sitename': '411 Fasanenstrasse (DB-Brücke)', 'lw': 0, 'directionname': '2 von Riehen (1=rechte S mit ÖV-Bus, 2=Unterführung)', 'lief0': 0, 'lanename': 'Spur 4', 'lief_aufl': 0, 'datetimeto': '2020-05-19T23:00:00+00:00', 'bus': 5, 'hourfrom': 23, 'traffictype': 'MIV', 'date': '20.05.2020', 'day': 20, 'pw': 8, 'valuesedited': 0, 'lw0': 0, 'datetimefrom': '2020-05-20T22:00:00+00:00', 'geo_point_2d': [47.573908258, 7.60222303084], 'timeto': '00:00', 'lanecode': 4, 'weekday': 2, 'mr': 0, 'sitecode': '00000411'}, 'geometry': {'type': 'Point', 'coordinates': [7.60222303084, 47.573908258]}, 'record_timestamp': '2020-05-22T06:52:06.659000+00:00'}, {'datasetid': '100006', 'recordid': '90bef1d7c3cb9c76e79f25a7a9a3a6fd41679672', 'fields': {'andere': 0, 'lief': 4, 'pw0': 0, 'sattelzug': 0, 'month': 5, 'zst_nr': '352', 'year': '2020', 'total': 127, 'timefr ...

# %%
data
# Out:
# {'nhits': 802248,
#  'parameters': {'dataset': '100006',
#   'timezone': 'UTC',
#   'rows': 10,
#   'sort': ['datetimefrom'],
#   'format': 'json',
#   'facet': ['zst_nr',
#    'sitename',
#    'datetimefrom',
#    'datetimeto',
#    'directionname',
#    'lanename',
#    'valuesapproved',
#    'valuesedited',
#    'year',
#    'month',
#    'day',
#    'weekday',
#    'timefrom']},
#  'records': [{'datasetid': '100006',
#    'recordid': '6402a1087c7a508d95bd2aff8668f4857a753fdf',
#    'fields': {'andere': 0,
#     'lief': 3,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '401',
#     'year': '2020',
#     'total': 55,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '401 Luzernerring-Brücke',
#     'lw': 0,
#     'directionname': '2 Flughafenstrasse',
#     'lief0': 0,
#     'lanename': 'Spur 2',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 0,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 52,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5699125893, 7.57284015165],
#     'timeto': '00:00',
#     'lanecode': 2,
#     'weekday': 2,
#     'mr': 0,
#     'sitecode': '00000401'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.57284015165, 47.5699125893]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': '8af3954dc0eb1ae29a5992952bf73ef5a79b9028',
#    'fields': {'andere': 0,
#     'lief': 5,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '420',
#     'year': '2020',
#     'total': 190,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '420 Nauenstrasse 73',
#     'lw': 0,
#     'directionname': '1 nach Grosspeter',
#     'lief0': 0,
#     'lanename': 'Spur 1',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 1,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 180,
#     'valuesedited': 0,
#     'lw0': 1,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5463057195, 7.59562321755],
#     'timeto': '00:00',
#     'lanecode': 1,
#     'weekday': 2,
#     'mr': 3,
#     'sitecode': '00000420'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.59562321755, 47.5463057195]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': 'c7aa48c0694143037d0c9ca6f935ba15b2db7cdf',
#    'fields': {'andere': 0,
#     'lief': 0,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '411',
#     'year': '2020',
#     'total': 12,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '411 Fasanenstrasse (DB-Brücke)',
#     'lw': 0,
#     'directionname': '2 von Riehen (1=rechte S mit ÖV-Bus, 2=Unterführung)',
#     'lief0': 0,
#     'lanename': 'Spur 3',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 0,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 11,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.573908258, 7.60222303084],
#     'timeto': '00:00',
#     'lanecode': 3,
#     'weekday': 2,
#     'mr': 1,
#     'sitecode': '00000411'},
#    'geometry': {'type': 'Point', 'coordinates': [7.60222303084, 47.573908258]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': 'faf3667b442488ea3157ac54e8d12f123695d573',
#    'fields': {'andere': 0,
#     'lief': 1,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '411',
#     'year': '2020',
#     'total': 14,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '411 Fasanenstrasse (DB-Brücke)',
#     'lw': 0,
#     'directionname': '2 von Riehen (1=rechte S mit ÖV-Bus, 2=Unterführung)',
#     'lief0': 0,
#     'lanename': 'Spur 4',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 5,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 8,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.573908258, 7.60222303084],
#     'timeto': '00:00',
#     'lanecode': 4,
#     'weekday': 2,
#     'mr': 0,
#     'sitecode': '00000411'},
#    'geometry': {'type': 'Point', 'coordinates': [7.60222303084, 47.573908258]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': '90bef1d7c3cb9c76e79f25a7a9a3a6fd41679672',
#    'fields': {'andere': 0,
#     'lief': 4,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '352',
#     'year': '2020',
#     'total': 127,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '352 Johanniterbrücke',
#     'lw': 0,
#     'directionname': 'von Kleinbasel (1 FS mit ÖV)',
#     'lief0': 0,
#     'lanename': 'Spur 2',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 4,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 105,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5654536123, 7.58754940334],
#     'timeto': '00:00',
#     'lanecode': 2,
#     'weekday': 2,
#     'mr': 14,
#     'sitecode': '00000352'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.58754940334, 47.5654536123]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': '87cc192149dcfbf2cc0ede709b8c066daca8a79f',
#    'fields': {'andere': 1,
#     'lief': 3,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '401',
#     'year': '2020',
#     'total': 28,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '401 Luzernerring-Brücke',
#     'lw': 0,
#     'directionname': '1 Elsässerstrasse',
#     'lief0': 0,
#     'lanename': 'Spur 1',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 0,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 24,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5699125893, 7.57284015165],
#     'timeto': '00:00',
#     'lanecode': 1,
#     'weekday': 2,
#     'mr': 0,
#     'sitecode': '00000401'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.57284015165, 47.5699125893]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': 'b33fc31c4b6f2ce218d26b759c09c488bef7b55e',
#    'fields': {'andere': 0,
#     'lief': 0,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '410',
#     'year': '2020',
#     'total': 0,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '410 St. Alban-Anlage 72',
#     'lw': 0,
#     'directionname': '1 von Bahnhof SBB',
#     'lief0': 0,
#     'lanename': 'Spur 1',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 0,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 0,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5527116018, 7.60459281521],
#     'timeto': '00:00',
#     'lanecode': 1,
#     'weekday': 2,
#     'mr': 0,
#     'sitecode': '00000410'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.60459281521, 47.5527116018]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': '0b90feecdf0a8a7e112f7b04c2467c85d4321383',
#    'fields': {'andere': 0,
#     'lief': 9,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '405',
#     'year': '2020',
#     'total': 127,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '405 Dorenbachviadukt',
#     'lw': 0,
#     'directionname': '1 nach Bahnhof SBB (ohne ÖV-Bus)',
#     'lief0': 0,
#     'lanename': 'Spur 1',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 0,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 108,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5441974089, 7.5771044978],
#     'timeto': '00:00',
#     'lanecode': 1,
#     'weekday': 2,
#     'mr': 10,
#     'sitecode': '00000405'},
#    'geometry': {'type': 'Point', 'coordinates': [7.5771044978, 47.5441974089]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': '7b026bd609e90dea936a2f9e8a15384b412c03c6',
#    'fields': {'andere': 0,
#     'lief': 0,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '408',
#     'year': '2020',
#     'total': 36,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '408 Bäumlihofstrasse (Riehen)',
#     'lw': 0,
#     'directionname': '1 nach Riehen (1 FS mit ÖV-Bus)',
#     'lief0': 0,
#     'lanename': 'Spur 1',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 5,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 28,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5704232117, 7.62859453432],
#     'timeto': '00:00',
#     'lanecode': 1,
#     'weekday': 2,
#     'mr': 3,
#     'sitecode': '00000408'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.62859453432, 47.5704232117]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'},
#   {'datasetid': '100006',
#    'recordid': 'd9621456a46e363d83fa521c0aaf4bd3170d5c39',
#    'fields': {'andere': 0,
#     'lief': 5,
#     'pw0': 0,
#     'sattelzug': 0,
#     'month': 5,
#     'zst_nr': '408',
#     'year': '2020',
#     'total': 98,
#     'timefrom': '23:00',
#     'valuesapproved': 0,
#     'sitename': '408 Bäumlihofstrasse (Riehen)',
#     'lw': 0,
#     'directionname': '2 nach Basel (1 FS mit ÖV-Bus)',
#     'lief0': 0,
#     'lanename': 'Spur 2',
#     'lief_aufl': 0,
#     'datetimeto': '2020-05-19T23:00:00+00:00',
#     'bus': 4,
#     'hourfrom': 23,
#     'traffictype': 'MIV',
#     'date': '20.05.2020',
#     'day': 20,
#     'pw': 84,
#     'valuesedited': 0,
#     'lw0': 0,
#     'datetimefrom': '2020-05-20T22:00:00+00:00',
#     'geo_point_2d': [47.5704232117, 7.62859453432],
#     'timeto': '00:00',
#     'lanecode': 2,
#     'weekday': 2,
#     'mr': 5,
#     'sitecode': '00000408'},
#    'geometry': {'type': 'Point',
#     'coordinates': [7.62859453432, 47.5704232117]},
#    'record_timestamp': '2020-05-22T06:52:06.659000+00:00'}],
#  'facet_groups': [{'facets': [{'count': 33427,
#      'path': '00:00',
#      'state': 'displayed',
#      'name': '00:00'},
#     {'count': 33427, 'path': '01:00', 'state': 'displayed', 'name': '01:00'},
#     {'count': 33427, 'path': '02:00', 'state': 'displayed', 'name': '02:00'},
#     {'count': 33427, 'path': '03:00', 'state': 'displayed', 'name': '03:00'},
#     {'count': 33427, 'path': '04:00', 'state': 'displayed', 'name': '04:00'},
#     {'count': 33427, 'path': '05:00', 'state': 'displayed', 'name': '05:00'},
#     {'count': 33427, 'path': '06:00', 'state': 'displayed', 'name': '06:00'},
#     {'count': 33427, 'path': '07:00', 'state': 'displayed', 'name': '07:00'},
#     {'count': 33427, 'path': '08:00', 'state': 'displayed', 'name': '08:00'},
#     {'count': 33427, 'path': '09:00', 'state': 'displayed', 'name': '09:00'},
#     {'count': 33427, 'path': '10:00', 'state': 'displayed', 'name': '10:00'},
#     {'count': 33427, 'path': '11:00', 'state': 'displayed', 'name': '11:00'},
#     {'count': 33427, 'path': '12:00', 'state': 'displayed', 'name': '12:00'},
#     {'count': 33427, 'path': '13:00', 'state': 'displayed', 'name': '13:00'},
#     {'count': 33427, 'path': '14:00', 'state': 'displayed', 'name': '14:00'},
#     {'count': 33427, 'path': '15:00', 'state': 'displayed', 'name': '15:00'},
#     {'count': 33427, 'path': '16:00', 'state': 'displayed', 'name': '16:00'},
#     {'count': 33427, 'path': '17:00', 'state': 'displayed', 'name': '17:00'},
#     {'count': 33427, 'path': '18:00', 'state': 'displayed', 'name': '18:00'},
#     {'count': 33427, 'path': '19:00', 'state': 'displayed', 'name': '19:00'},
#     {'count': 33427, 'path': '20:00', 'state': 'displayed', 'name': '20:00'},
#     {'count': 33427, 'path': '21:00', 'state': 'displayed', 'name': '21:00'},
#     {'count': 33427, 'path': '22:00', 'state': 'displayed', 'name': '22:00'},
#     {'count': 33427, 'path': '23:00', 'state': 'displayed', 'name': '23:00'}],
#    'name': 'timefrom'},
#   {'facets': [{'count': 773136,
#      'path': '1',
#      'state': 'displayed',
#      'name': '1'},
#     {'count': 29112, 'path': '0', 'state': 'displayed', 'name': '0'}],
#    'name': 'valuesapproved'},
#   {'facets': [{'count': 69,
#      'path': '2018',
#      'state': 'displayed',
#      'name': '2018'},
#     {'count': 580102, 'path': '2019', 'state': 'displayed', 'name': '2019'},
#     {'count': 222077, 'path': '2020', 'state': 'displayed', 'name': '2020'}],
#    'name': 'datetimeto'},
#   {'facets': [{'count': 60600,
#      'path': '350 Dreirosenbrücke lokal (mit Ein- Ausfahrten)',
#      'state': 'displayed',
#      'name': '350 Dreirosenbrücke lokal (mit Ein- Ausfahrten)'},
#     {'count': 48576,
#      'path': '403 Heuwaage-Viadukt',
#      'state': 'displayed',
#      'name': '403 Heuwaage-Viadukt'},
#     {'count': 48576,
#      'path': '411 Fasanenstrasse (DB-Brücke)',
#      'state': 'displayed',
#      'name': '411 Fasanenstrasse (DB-Brücke)'},
#     {'count': 48576,
#      'path': '420 Nauenstrasse 73',
#      'state': 'displayed',
#      'name': '420 Nauenstrasse 73'},
#     {'count': 36432,
#      'path': '415 Grosspeterstrasse 45',
#      'state': 'displayed',
#      'name': '415 Grosspeterstrasse 45'},
#     {'count': 24288,
#      'path': '235 A3-A35, Grenze CH-F',
#      'state': 'displayed',
#      'name': '235 A3-A35, Grenze CH-F'},
#     {'count': 24288,
#      'path': '352 Johanniterbrücke',
#      'state': 'displayed',
#      'name': '352 Johanniterbrücke'},
#     {'count': 24288,
#      'path': '401 Luzernerring-Brücke',
#      'state': 'displayed',
#      'name': '401 Luzernerring-Brücke'},
#     {'count': 24288,
#      'path': '405 Dorenbachviadukt',
#      'state': 'displayed',
#      'name': '405 Dorenbachviadukt'},
#     {'count': 24288,
#      'path': '406 Wasgenring 62',
#      'state': 'displayed',
#      'name': '406 Wasgenring 62'},
#     {'count': 24288,
#      'path': '408 Bäumlihofstrasse (Riehen)',
#      'state': 'displayed',
#      'name': '408 Bäumlihofstrasse (Riehen)'},
#     {'count': 24288,
#      'path': '409 Grenzacherstrasse 511',
#      'state': 'displayed',
#      'name': '409 Grenzacherstrasse 511'},
#     {'count': 24288,
#      'path': '410 St. Alban-Anlage 72',
#      'state': 'displayed',
#      'name': '410 St. Alban-Anlage 72'},
#     {'count': 24288,
#      'path': '412 Dornacherstrasse 49',
#      'state': 'displayed',
#      'name': '412 Dornacherstrasse 49'},
#     {'count': 24288,
#      'path': '419 Riehenring 120',
#      'state': 'displayed',
#      'name': '419 Riehenring 120'},
#     {'count': 24288,
#      'path': '651 Entenweidstrasse 74',
#      'state': 'displayed',
#      'name': '651 Entenweidstrasse 74'},
#     {'count': 24288,
#      'path': '670 Zoll CH-D, Hiltalingerstrasse',
#      'state': 'displayed',
#      'name': '670 Zoll CH-D, Hiltalingerstrasse'},
#     {'count': 24288,
#      'path': '671 Zoll CH-D, Freiburgerstrasse',
#      'state': 'displayed',
#      'name': '671 Zoll CH-D, Freiburgerstrasse'},
#     {'count': 24288,
#      'path': '672 Zoll CH-D, Weilstrasse',
#      'state': 'displayed',
#      'name': '672 Zoll CH-D, Weilstrasse'},
#     {'count': 24144,
#      'path': '402 Hochbergerstrasse 55',
#      'state': 'displayed',
#      'name': '402 Hochbergerstrasse 55'},
#     {'count': 24144,
#      'path': '659 Schlachthofstrasse',
#      'state': 'displayed',
#      'name': '659 Schlachthofstrasse'},
#     {'count': 24096,
#      'path': '413 Gundeldingerstrasse 107',
#      'state': 'displayed',
#      'name': '413 Gundeldingerstrasse 107'},
#     {'count': 23712,
#      'path': '354 Wettsteinbrücke',
#      'state': 'displayed',
#      'name': '354 Wettsteinbrücke'},
#     {'count': 23712,
#      'path': '404 Viaduktstrasse 60 (Rialto)',
#      'state': 'displayed',
#      'name': '404 Viaduktstrasse 60 (Rialto)'},
#     {'count': 21456,
#      'path': '660 Flughafenstrasse, Grenze CH-F',
#      'state': 'displayed',
#      'name': '660 Flughafenstrasse, Grenze CH-F'},
#     {'count': 20376,
#      'path': '673 Zoll CH-D, Lörracherstrasse',
#      'state': 'displayed',
#      'name': '673 Zoll CH-D, Lörracherstrasse'},
#     {'count': 14448,
#      'path': '653 Flughafenstrasse 30',
#      'state': 'displayed',
#      'name': '653 Flughafenstrasse 30'},
#     {'count': 12144,
#      'path': '416 J. Burckhardt-Strasse 85',
#      'state': 'displayed',
#      'name': '416 J. Burckhardt-Strasse 85'},
#     {'count': 12144,
#      'path': '417 Sevogelstrasse 82',
#      'state': 'displayed',
#      'name': '417 Sevogelstrasse 82'},
#     {'count': 12144,
#      'path': '656 Elsässerstrasse 146',
#      'state': 'displayed',
#      'name': '656 Elsässerstrasse 146'},
#     {'count': 5520,
#      'path': '414 Gundeldingerstrasse 428',
#      'state': 'displayed',
#      'name': '414 Gundeldingerstrasse 428'},
#     {'count': 1416,
#      'path': '407 Äussere Baselstrasse 381 (Riehen)',
#      'state': 'displayed',
#      'name': '407 Äussere Baselstrasse 381 (Riehen)'}],
#    'name': 'sitename'},
#   {'facets': [{'count': 69,
#      'path': '2018',
#      'state': 'displayed',
#      'name': '2018'},
#     {'count': 580102, 'path': '2019', 'state': 'displayed', 'name': '2019'},
#     {'count': 222077, 'path': '2020', 'state': 'displayed', 'name': '2020'}],
#    'name': 'datetimefrom'},
#   {'facets': [{'count': 100488,
#      'path': '1',
#      'state': 'displayed',
#      'name': '1'},
#     {'count': 98208, 'path': '3', 'state': 'displayed', 'name': '3'},
#     {'count': 94608, 'path': '4', 'state': 'displayed', 'name': '4'},
#     {'count': 91848, 'path': '2', 'state': 'displayed', 'name': '2'},
#     {'count': 78768, 'path': '5', 'state': 'displayed', 'name': '5'},
#     {'count': 49848, 'path': '12', 'state': 'displayed', 'name': '12'},
#     {'count': 49104, 'path': '7', 'state': 'displayed', 'name': '7'},
#     {'count': 48792, 'path': '8', 'state': 'displayed', 'name': '8'},
#     {'count': 48360, 'path': '10', 'state': 'displayed', 'name': '10'},
#     {'count': 48240, 'path': '11', 'state': 'displayed', 'name': '11'},
#     {'count': 47184, 'path': '6', 'state': 'displayed', 'name': '6'},
#     {'count': 46800, 'path': '9', 'state': 'displayed', 'name': '9'}],
#    'name': 'month'},
#   {'facets': [{'count': 60600,
#      'path': '350',
#      'state': 'displayed',
#      'name': '350'},
#     {'count': 48576, 'path': '403', 'state': 'displayed', 'name': '403'},
#     {'count': 48576, 'path': '411', 'state': 'displayed', 'name': '411'},
#     {'count': 48576, 'path': '420', 'state': 'displayed', 'name': '420'},
#     {'count': 36432, 'path': '415', 'state': 'displayed', 'name': '415'},
#     {'count': 24288, 'path': '235', 'state': 'displayed', 'name': '235'},
#     {'count': 24288, 'path': '352', 'state': 'displayed', 'name': '352'},
#     {'count': 24288, 'path': '401', 'state': 'displayed', 'name': '401'},
#     {'count': 24288, 'path': '405', 'state': 'displayed', 'name': '405'},
#     {'count': 24288, 'path': '406', 'state': 'displayed', 'name': '406'},
#     {'count': 24288, 'path': '408', 'state': 'displayed', 'name': '408'},
#     {'count': 24288, 'path': '409', 'state': 'displayed', 'name': '409'},
#     {'count': 24288, 'path': '410', 'state': 'displayed', 'name': '410'},
#     {'count': 24288, 'path': '412', 'state': 'displayed', 'name': '412'},
#     {'count': 24288, 'path': '419', 'state': 'displayed', 'name': '419'},
#     {'count': 24288, 'path': '651', 'state': 'displayed', 'name': '651'},
#     {'count': 24288, 'path': '670', 'state': 'displayed', 'name': '670'},
#     {'count': 24288, 'path': '671', 'state': 'displayed', 'name': '671'},
#     {'count': 24288, 'path': '672', 'state': 'displayed', 'name': '672'},
#     {'count': 24144, 'path': '402', 'state': 'displayed', 'name': '402'},
#     {'count': 24144, 'path': '659', 'state': 'displayed', 'name': '659'},
#     {'count': 24096, 'path': '413', 'state': 'displayed', 'name': '413'},
#     {'count': 23712, 'path': '354', 'state': 'displayed', 'name': '354'},
#     {'count': 23712, 'path': '404', 'state': 'displayed', 'name': '404'},
#     {'count': 21456, 'path': '660', 'state': 'displayed', 'name': '660'},
#     {'count': 20376, 'path': '673', 'state': 'displayed', 'name': '673'},
#     {'count': 14448, 'path': '653', 'state': 'displayed', 'name': '653'},
#     {'count': 12144, 'path': '416', 'state': 'displayed', 'name': '416'},
#     {'count': 12144, 'path': '417', 'state': 'displayed', 'name': '417'},
#     {'count': 12144, 'path': '656', 'state': 'displayed', 'name': '656'},
#     {'count': 5520, 'path': '414', 'state': 'displayed', 'name': '414'},
#     {'count': 1416, 'path': '407', 'state': 'displayed', 'name': '407'}],
#    'name': 'zst_nr'},
#   {'facets': [{'count': 36360,
#      'path': 'von Kleinbasel',
#      'state': 'displayed',
#      'name': 'von Kleinbasel'},
#     {'count': 25704,
#      'path': '1 nach Riehen (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 nach Riehen (1 FS mit ÖV-Bus)'},
#     {'count': 24288,
#      'path': '1 nach Bahnhof SBB (1=R, 2=Ü)',
#      'state': 'displayed',
#      'name': '1 nach Bahnhof SBB (1=R, 2=Ü)'},
#     {'count': 24288,
#      'path': '1 nach Deutschland',
#      'state': 'displayed',
#      'name': '1 nach Deutschland'},
#     {'count': 24288,
#      'path': '1 nach Grosspeter',
#      'state': 'displayed',
#      'name': '1 nach Grosspeter'},
#     {'count': 24288,
#      'path': '1 nach Riehen (1=rechte S, 2=Unterführung mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 nach Riehen (1=rechte S, 2=Unterführung mit ÖV-Bus)'},
#     {'count': 24288,
#      'path': '1 von Bahnhof SBB  (1+2 FS)',
#      'state': 'displayed',
#      'name': '1 von Bahnhof SBB  (1+2 FS)'},
#     {'count': 24288,
#      'path': '2 nach Bahnhof SBB',
#      'state': 'displayed',
#      'name': '2 nach Bahnhof SBB'},
#     {'count': 24288,
#      'path': '2 von Bahnhof SBB (1=R, 2=Ü)',
#      'state': 'displayed',
#      'name': '2 von Bahnhof SBB (1=R, 2=Ü)'},
#     {'count': 24288,
#      'path': '2 von Grosspeter',
#      'state': 'displayed',
#      'name': '2 von Grosspeter'},
#     {'count': 24288,
#      'path': '2 von Riehen (1=rechte S mit ÖV-Bus, 2=Unterführung)',
#      'state': 'displayed',
#      'name': '2 von Riehen (1=rechte S mit ÖV-Bus, 2=Unterführung)'},
#     {'count': 24288,
#      'path': 'von Dreispitz (1+2 FS, 1=rechte FS mit öV-Bus)',
#      'state': 'displayed',
#      'name': 'von Dreispitz (1+2 FS, 1=rechte FS mit öV-Bus)'},
#     {'count': 24240,
#      'path': 'nach Kleinbasel',
#      'state': 'displayed',
#      'name': 'nach Kleinbasel'},
#     {'count': 24096,
#      'path': 'nach Dreispitz (1+2 FS, 1=rechte FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': 'nach Dreispitz (1+2 FS, 1=rechte FS mit ÖV-Bus)'},
#     {'count': 20376,
#      'path': '2 von Deutschland',
#      'state': 'displayed',
#      'name': '2 von Deutschland'},
#     {'count': 12144,
#      'path': '1 Elsässerstrasse',
#      'state': 'displayed',
#      'name': '1 Elsässerstrasse'},
#     {'count': 12144,
#      'path': '1 nach Bahnhof SBB (ohne ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 nach Bahnhof SBB (ohne ÖV-Bus)'},
#     {'count': 12144,
#      'path': '1 nach Deutschland (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 nach Deutschland (1 FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': '1 nach Neubad (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 nach Neubad (1 FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': '1 von Bahnhof SBB',
#      'state': 'displayed',
#      'name': '1 von Bahnhof SBB'},
#     {'count': 12144,
#      'path': '1 von Deutschland',
#      'state': 'displayed',
#      'name': '1 von Deutschland'},
#     {'count': 12144,
#      'path': '1 von Feldbergstrasse (1 FS bei Tramhaltestelle)',
#      'state': 'displayed',
#      'name': '1 von Feldbergstrasse (1 FS bei Tramhaltestelle)'},
#     {'count': 12144,
#      'path': '1 von Frankreich',
#      'state': 'displayed',
#      'name': '1 von Frankreich'},
#     {'count': 12144,
#      'path': '1 von Kannenfeldplatz',
#      'state': 'displayed',
#      'name': '1 von Kannenfeldplatz'},
#     {'count': 12144,
#      'path': '2 Flughafenstrasse',
#      'state': 'displayed',
#      'name': '2 Flughafenstrasse'},
#     {'count': 12144,
#      'path': '2 nach Basel (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 nach Basel (1 FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': '2 nach Deutschland',
#      'state': 'displayed',
#      'name': '2 nach Deutschland'},
#     {'count': 12144,
#      'path': '2 nach Feldbergstrasse (1 FS bei Tramhaltestelle)',
#      'state': 'displayed',
#      'name': '2 nach Feldbergstrasse (1 FS bei Tramhaltestelle)'},
#     {'count': 12144,
#      'path': '2 nach Kannenfeldplatz',
#      'state': 'displayed',
#      'name': '2 nach Kannenfeldplatz'},
#     {'count': 12144,
#      'path': '2 von Bahnhof SBB (ohne ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 von Bahnhof SBB (ohne ÖV-Bus)'},
#     {'count': 12144,
#      'path': '2 von Deutschland (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 von Deutschland (1 FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': '2 von Neubad (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 von Neubad (1 FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': '2 von Riehen (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 von Riehen (1 FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': 'nach Bahnhof SBB (1FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': 'nach Bahnhof SBB (1FS mit ÖV-Bus)'},
#     {'count': 12144,
#      'path': 'nach Frankreich',
#      'state': 'displayed',
#      'name': 'nach Frankreich'},
#     {'count': 12144,
#      'path': 'nach Kleinbasel (1 FS mit ÖV)',
#      'state': 'displayed',
#      'name': 'nach Kleinbasel (1 FS mit ÖV)'},
#     {'count': 12144,
#      'path': 'von Frankreich',
#      'state': 'displayed',
#      'name': 'von Frankreich'},
#     {'count': 12144,
#      'path': 'von Gundeldingen (1 FS)',
#      'state': 'displayed',
#      'name': 'von Gundeldingen (1 FS)'},
#     {'count': 12144,
#      'path': 'von Kleinbasel (1 FS mit ÖV)',
#      'state': 'displayed',
#      'name': 'von Kleinbasel (1 FS mit ÖV)'},
#     {'count': 12072,
#      'path': '1 von Autobahnz. F',
#      'state': 'displayed',
#      'name': '1 von Autobahnz. F'},
#     {'count': 12072,
#      'path': '1 von Rhein (1FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 von Rhein (1FS mit ÖV-Bus)'},
#     {'count': 12072,
#      'path': '2 nach Autobahnz. F',
#      'state': 'displayed',
#      'name': '2 nach Autobahnz. F'},
#     {'count': 12072,
#      'path': '2 nach Rhein (1FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 nach Rhein (1FS mit ÖV-Bus)'},
#     {'count': 11856,
#      'path': '1 nach Bahnhof SBB (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 nach Bahnhof SBB (1 FS mit ÖV-Bus)'},
#     {'count': 11856,
#      'path': '1 nach Kleinbasel',
#      'state': 'displayed',
#      'name': '1 nach Kleinbasel'},
#     {'count': 11856,
#      'path': '2 von Bahnhof SBB (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 von Bahnhof SBB (1 FS mit ÖV-Bus)'},
#     {'count': 11856,
#      'path': '2 von Kleinbasel',
#      'state': 'displayed',
#      'name': '2 von Kleinbasel'},
#     {'count': 10728,
#      'path': '1 von Flughafen (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 von Flughafen (1 FS mit ÖV-Bus)'},
#     {'count': 10728,
#      'path': '2 nach Flughafen (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 nach Flughafen (1 FS mit ÖV-Bus)'},
#     {'count': 7224,
#      'path': '1 von Frankreich (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '1 von Frankreich (1 FS mit ÖV-Bus)'},
#     {'count': 7224,
#      'path': '2 nach Frankreich (1 FS mit ÖV-Bus)',
#      'state': 'displayed',
#      'name': '2 nach Frankreich (1 FS mit ÖV-Bus)'},
#     {'count': 5520,
#      'path': 'nach Dreispitz',
#      'state': 'displayed',
#      'name': 'nach Dreispitz'}],
#    'name': 'directionname'},
#   {'facets': [{'count': 115776,
#      'path': '1',
#      'state': 'displayed',
#      'name': '1'},
#     {'count': 115728, 'path': '2', 'state': 'displayed', 'name': '2'},
#     {'count': 114264, 'path': '4', 'state': 'displayed', 'name': '4'},
#     {'count': 114192, 'path': '5', 'state': 'displayed', 'name': '5'},
#     {'count': 114192, 'path': '6', 'state': 'displayed', 'name': '6'},
#     {'count': 114072, 'path': '3', 'state': 'displayed', 'name': '3'},
#     {'count': 114024, 'path': '0', 'state': 'displayed', 'name': '0'}],
#    'name': 'weekday'},
#   {'facets': [{'count': 580104,
#      'path': '2019',
#      'state': 'displayed',
#      'name': '2019'},
#     {'count': 222144, 'path': '2020', 'state': 'displayed', 'name': '2020'}],
#    'name': 'year'},
#   {'facets': [{'count': 364080,
#      'path': 'Spur 1',
#      'state': 'displayed',
#      'name': 'Spur 1'},
#     {'count': 308568,
#      'path': 'Spur 2',
#      'state': 'displayed',
#      'name': 'Spur 2'},
#     {'count': 56784, 'path': 'Spur 4', 'state': 'displayed', 'name': 'Spur 4'},
#     {'count': 48576, 'path': 'Spur 3', 'state': 'displayed', 'name': 'Spur 3'},
#     {'count': 12120, 'path': 'Spur 5', 'state': 'displayed', 'name': 'Spur 5'},
#     {'count': 12120,
#      'path': 'Spur 6',
#      'state': 'displayed',
#      'name': 'Spur 6'}],
#    'name': 'lanename'},
#   {'facets': [{'count': 27072, 'path': '1', 'state': 'displayed', 'name': '1'},
#     {'count': 27048, 'path': '3', 'state': 'displayed', 'name': '3'},
#     {'count': 27048, 'path': '5', 'state': 'displayed', 'name': '5'},
#     {'count': 27048, 'path': '6', 'state': 'displayed', 'name': '6'},
#     {'count': 27048, 'path': '8', 'state': 'displayed', 'name': '8'},
#     {'count': 27024, 'path': '2', 'state': 'displayed', 'name': '2'},
#     {'count': 27000, 'path': '4', 'state': 'displayed', 'name': '4'},
#     {'count': 27000, 'path': '9', 'state': 'displayed', 'name': '9'},
#     {'count': 26928, 'path': '15', 'state': 'displayed', 'name': '15'},
#     {'count': 26928, 'path': '16', 'state': 'displayed', 'name': '16'},
#     {'count': 26904, 'path': '10', 'state': 'displayed', 'name': '10'},
#     {'count': 26904, 'path': '11', 'state': 'displayed', 'name': '11'},
#     {'count': 26904, 'path': '12', 'state': 'displayed', 'name': '12'},
#     {'count': 26904, 'path': '13', 'state': 'displayed', 'name': '13'},
#     {'count': 26904, 'path': '14', 'state': 'displayed', 'name': '14'},
#     {'count': 26880, 'path': '7', 'state': 'displayed', 'name': '7'},
#     {'count': 26880, 'path': '17', 'state': 'displayed', 'name': '17'},
#     {'count': 26856, 'path': '19', 'state': 'displayed', 'name': '19'},
#     {'count': 26808, 'path': '20', 'state': 'displayed', 'name': '20'},
#     {'count': 26784, 'path': '18', 'state': 'displayed', 'name': '18'},
#     {'count': 25392, 'path': '21', 'state': 'displayed', 'name': '21'},
#     {'count': 25392, 'path': '22', 'state': 'displayed', 'name': '22'},
#     {'count': 25392, 'path': '23', 'state': 'displayed', 'name': '23'},
#     {'count': 25392, 'path': '24', 'state': 'displayed', 'name': '24'},
#     {'count': 25392, 'path': '25', 'state': 'displayed', 'name': '25'},
#     {'count': 25392, 'path': '26', 'state': 'displayed', 'name': '26'},
#     {'count': 25392, 'path': '27', 'state': 'displayed', 'name': '27'},
#     {'count': 25392, 'path': '28', 'state': 'displayed', 'name': '28'},
#     {'count': 23760, 'path': '29', 'state': 'displayed', 'name': '29'},
#     {'count': 22200, 'path': '30', 'state': 'displayed', 'name': '30'},
#     {'count': 14280, 'path': '31', 'state': 'displayed', 'name': '31'}],
#    'name': 'day'},
#   {'facets': [{'count': 784175,
#      'path': '0',
#      'state': 'displayed',
#      'name': '0'},
#     {'count': 18073, 'path': '1', 'state': 'displayed', 'name': '1'}],
#    'name': 'valuesedited'}]}

# %%
df = pd.json_normalize(data["records"])

# %%
df.columns = df.columns.str.replace("fields.", "")

# %%
df
# Out:
#   datasetid                                  recordid  \
# 0    100006  6402a1087c7a508d95bd2aff8668f4857a753fdf
# 1    100006  8af3954dc0eb1ae29a5992952bf73ef5a79b9028
# 2    100006  c7aa48c0694143037d0c9ca6f935ba15b2db7cdf
# 3    100006  faf3667b442488ea3157ac54e8d12f123695d573
# 4    100006  90bef1d7c3cb9c76e79f25a7a9a3a6fd41679672
# 5    100006  87cc192149dcfbf2cc0ede709b8c066daca8a79f
# 6    100006  b33fc31c4b6f2ce218d26b759c09c488bef7b55e
# 7    100006  0b90feecdf0a8a7e112f7b04c2467c85d4321383
# 8    100006  7b026bd609e90dea936a2f9e8a15384b412c03c6
# 9    100006  d9621456a46e363d83fa521c0aaf4bd3170d5c39
#
#                    record_timestamp  andere  lief  pw0  sattelzug  month  \
# 0  2020-05-22T06:52:06.659000+00:00       0     3    0          0      5
# 1  2020-05-22T06:52:06.659000+00:00       0     5    0          0      5
# 2  2020-05-22T06:52:06.659000+00:00       0     0    0          0      5
# 3  2020-05-22T06:52:06.659000+00:00       0     1    0          0      5
# 4  2020-05-22T06:52:06.659000+00:00       0     4    0          0      5
# 5  2020-05-22T06:52:06.659000+00:00       1     3    0          0      5
# 6  2020-05-22T06:52:06.659000+00:00       0     0    0          0      5
# 7  2020-05-22T06:52:06.659000+00:00       0     9    0          0      5
# 8  2020-05-22T06:52:06.659000+00:00       0     0    0          0      5
# 9  2020-05-22T06:52:06.659000+00:00       0     5    0          0      5
#
#   zst_nr  year  ...  lw0               datetimefrom  \
# 0    401  2020  ...    0  2020-05-20T22:00:00+00:00
# 1    420  2020  ...    1  2020-05-20T22:00:00+00:00
# 2    411  2020  ...    0  2020-05-20T22:00:00+00:00
# 3    411  2020  ...    0  2020-05-20T22:00:00+00:00
# 4    352  2020  ...    0  2020-05-20T22:00:00+00:00
# 5    401  2020  ...    0  2020-05-20T22:00:00+00:00
# 6    410  2020  ...    0  2020-05-20T22:00:00+00:00
# 7    405  2020  ...    0  2020-05-20T22:00:00+00:00
# 8    408  2020  ...    0  2020-05-20T22:00:00+00:00
# 9    408  2020  ...    0  2020-05-20T22:00:00+00:00
#
#                      geo_point_2d timeto  lanecode weekday  mr  sitecode  \
# 0  [47.5699125893, 7.57284015165]  00:00         2       2   0  00000401
# 1  [47.5463057195, 7.59562321755]  00:00         1       2   3  00000420
# 2   [47.573908258, 7.60222303084]  00:00         3       2   1  00000411
# 3   [47.573908258, 7.60222303084]  00:00         4       2   0  00000411
# 4  [47.5654536123, 7.58754940334]  00:00         2       2  14  00000352
# 5  [47.5699125893, 7.57284015165]  00:00         1       2   0  00000401
# 6  [47.5527116018, 7.60459281521]  00:00         1       2   0  00000410
# 7   [47.5441974089, 7.5771044978]  00:00         1       2  10  00000405
# 8  [47.5704232117, 7.62859453432]  00:00         1       2   3  00000408
# 9  [47.5704232117, 7.62859453432]  00:00         2       2   5  00000408
#
#    geometry.type            geometry.coordinates
# 0          Point  [7.57284015165, 47.5699125893]
# 1          Point  [7.59562321755, 47.5463057195]
# 2          Point   [7.60222303084, 47.573908258]
# 3          Point   [7.60222303084, 47.573908258]
# 4          Point  [7.58754940334, 47.5654536123]
# 5          Point  [7.57284015165, 47.5699125893]
# 6          Point  [7.60459281521, 47.5527116018]
# 7          Point   [7.5771044978, 47.5441974089]
# 8          Point  [7.62859453432, 47.5704232117]
# 9          Point  [7.62859453432, 47.5704232117]
#
# [10 rows x 37 columns]

# %%
pd.read_json(url_cars)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-6d333a739803> in <module>
# ----> 1 pd.read_json(url_cars)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     606         return json_reader
#     607
# --> 608     result = json_reader.read()
#     609     if should_close:
#     610         filepath_or_buffer.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     729             obj = self._get_object_parser(self._combine_lines(data.split("\n")))
#     730         else:
# --> 731             obj = self._get_object_parser(self.data)
#     732         self.close()
#     733         return obj
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     751         obj = None
#     752         if typ == "frame":
# --> 753             obj = FrameParser(json, **kwargs).parse()
#     754
#     755         if typ == "series" or obj is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     855
#     856         else:
# --> 857             self._parse_no_numpy()
#     858
#     859         if self.obj is None:
#
# ~\anaconda3\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1087         if orient == "columns":
#    1088             self.obj = DataFrame(
# -> 1089                 loads(json, precise_float=self.precise_float), dtype=None
#    1090             )
#    1091         elif orient == "split":
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433             )
#     434         elif isinstance(data, dict):
# --> 435             mgr = init_dict(data, index, columns, dtype=dtype)
#     436         elif isinstance(data, ma.MaskedArray):
#     437             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     252             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     253         ]
# --> 254     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     255
#     256
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      62     # figure out the index, if necessary
#      63     if index is None:
# ---> 64         index = extract_index(arrays)
#      65     else:
#      66         index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     363             lengths = list(set(raw_lengths))
#     364             if len(lengths) > 1:
# --> 365                 raise ValueError("arrays must all be same length")
#     366
#     367             if have_dicts:
#
# ValueError: arrays must all be same length
